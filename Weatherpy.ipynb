# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# %%
df=pd.read_csv(r"C:\Users\Cindy Ngo\python-api-challenge\WeatherPy\cities.csv",encoding="utf")
df
# Out:
#      City_ID         City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0    ostrovnoy           2      RU  1558378754        72  68.05
# 1          1    mahebourg          75      MU  1558378503        74 -20.41
# 2          2      qaanaaq          25      GL  1558378755        73  77.48
# 3          3       zhuhai           0      CN  1558378755        39  40.71
# 4          4    cape town          20      ZA  1558378755        76 -33.93
# ..       ...          ...         ...     ...         ...       ...    ...
# 543      543       yabrud           0      SY  1558378840        32  33.97
# 544      544      paraiso           5      MX  1558378898         4  24.01
# 545      545      veraval           0      FR  1558378898        62  49.65
# 546      546  novyy urgal         100      RU  1558378899        93  51.07
# 547      547      tongren           4      CN  1558378899        64  27.72
#
#         Lng  Max Temp  Wind Speed
# ...

# %%
df.head(3)
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05  39.51
# 1        1  mahebourg          75      MU  1558378503        74 -20.41  57.70
# 2        2    qaanaaq          25      GL  1558378755        73  77.48 -69.36
#
#    Max Temp  Wind Speed
# 0      37.5        7.16
# 1      78.8       11.41
# 2      22.2        2.37

# %%
plt.scatter(df["Lat"], df["Max Temp"], marker="o", s=10)

plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.show()

# %%
plt.scatter(df["Lat"], df["Humidity"], marker="o", s=10)

plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)



plt.show()

# %%
plt.scatter(df["Lat"], df["Cloudiness"], marker="o", s=10)


plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)



# Show plot
plt.show()

# %%
plt.scatter(df["Lat"],df["Wind Speed"], marker="o", s=10)


plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)





plt.show()

# %%
import statsmodels.api as sm
df.rename(columns={'Max Temp':'temp'},inplace=True)
y=df.temp
x=df.Lat
x=sm.add_constant(x)
model=sm.OLS(y,x)
model_fit=model.fit()
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   temp   R-squared:                       0.155
# Model:                            OLS   Adj. R-squared:                  0.153
# Method:                 Least Squares   F-statistic:                     100.1
# Date:                Tue, 29 Sep 2020   Prob (F-statistic):           9.47e-22
# Time:                        21:59:21   Log-Likelihood:                -2335.9
# No. Observations:                 548   AIC:                             4676.
# Df Residuals:                     546   BIC:                             4684.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         69.2766      0.852     81.321      0.000      67.603      70.950
# ...
