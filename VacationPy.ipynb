# %%
import googlemaps

# %%
gmaps=googlemaps.Client(key="AIzaSyAsHCsi3lB29rQSzoMAJhG7nwWA7EWe98A")
geocode_result=gmaps.geocode("1272 Rhode Island San Francisco California")
geocode_result
# Out:
# [{'address_components': [{'long_name': '1272',
#     'short_name': '1272',
#     'types': ['street_number']},
#    {'long_name': 'Rhode Island Street',
#     'short_name': 'Rhode Island St',
#     'types': ['route']},
#    {'long_name': 'Potrero Hill',
#     'short_name': 'Potrero Hill',
#     'types': ['neighborhood', 'political']},
#    {'long_name': 'San Francisco',
#     'short_name': 'SF',
#     'types': ['locality', 'political']},
#    {'long_name': 'San Francisco County',
#     'short_name': 'San Francisco County',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'California',
#     'short_name': 'CA',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']},
#    {'long_name': '94107', 'short_name': '94107', 'types': ['postal_code']},
#    {'long_name': '4405',
#     'short_name': '4405',
#     'types': ['postal_code_suffix']}],
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

df=pd.read_csv(r"C:\Users\Cindy Ngo\python-api-challenge\WeatherPy\cities.csv",encoding="utf")
df.head(3)
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05  39.51
# 1        1  mahebourg          75      MU  1558378503        74 -20.41  57.70
# 2        2    qaanaaq          25      GL  1558378755        73  77.48 -69.36
#
#    Max Temp  Wind Speed
# 0      37.5        7.16
# 1      78.8       11.41
# 2      22.2        2.37

# %%
import gmaps
import gmaps.datasets
gmaps.configure("AIzaSyAsHCsi3lB29rQSzoMAJhG7nwWA7EWe98A")
m=gmaps.Map()
df['geodata']=df.iloc[:,1:].apply(lambda x: (x.values[5],x.values[6]),axis=1)
df.head(3)
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05  39.51
# 1        1  mahebourg          75      MU  1558378503        74 -20.41  57.70
# 2        2    qaanaaq          25      GL  1558378755        73  77.48 -69.36
#
#    Max Temp  Wind Speed  Geodata          geodata
# 0      37.5        7.16    68.05   (68.05, 39.51)
# 1      78.8       11.41   -20.41   (-20.41, 57.7)
# 2      22.2        2.37    77.48  (77.48, -69.36)

# %%
df['geodata'].values.tolist()
# Out:
# [(68.05, 39.51),
#  (-20.41, 57.7),
#  (77.48, -69.36),
#  (40.71, 112.04),
#  (-33.93, 18.42),
#  (-9.8, -139.03),
#  (-34.58, 150.85),
#  (-18.06, 13.84),
#  (71.64, 128.87),
#  (57.02, 28.91),
#  (65.95, 111.51),
#  (-42.48, -73.76),
#  (-21.21, -159.78),
#  (71.97, 114.09),
#  (23.99, -104.67),
#  (42.65, -73.75),
#  (63.75, 121.63),
#  (-54.81, -68.31),
#  (-20.34, 57.76),
#  (58.6, 99.18),
#  (20.86, 92.31),
#  (-33.64, 115.35),
#  (47.55, -2.56),
#  (-9.01, -35.22),
#  (46.84, -105.12),
#  (7.42, 99.52),
#  (27.13, 81.7),
#  (-53.16, -70.91),
#  (-23.12, -134.97),
#  (-42.78, 147.06),
#  (-22.45, 18.97),
#  (36.09, 120.35),
#  (50.7, -127.42),
#  (59.7, 150.17),
#  (57.82, 114.02),
#  (60.79, -161.76),
#  (41.84, -90.19),
#  (58.61, 5.65),
#  (40.67, 33.6),
#  (-19.93, -60.77),
#  (-34.42, 19.24),
#  (47.66, -52.73),
#  (62.45, -114.38),
#  (-34.0, 24.73),
#  (-0.74, -90.35),
#  (13.92, -84.4),
#  (-25.17, 45.06),
#  (39.31, -74.98),
#  (-33.59, 26.89),
#  (13.88, 123.7),
# ...

# %%
heatmap_layer=gmaps.Heatmap(data=df['geodata'].values.tolist())
m.add_layer(heatmap_layer)
m
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\traitlets\traitlets.py in get(self, obj, cls)
#     527         try:
# --> 528             value = obj._trait_values[self.name]
#     529         except KeyError:
#
# KeyError: 'locations'
#
# During handling of the above exception, another exception occurred:
#
# TraitError                                Traceback (most recent call last)
# <ipython-input-62-72ba85b91209> in <module>
# ----> 1 heatmap_layer=gmaps.Heatmap(data=df['geodata'].values.tolist())
#       2 m.add_layer(heatmap_layer)
#       3 m
#
# ~\anaconda3\envs\PythonData\lib\site-packages\ipywidgets\widgets\widget.py in __init__(self, **kwargs)
#     413
#     414         Widget._call_widget_constructed(self)
# --> 415         self.open()
#     416
#     417     def __del__(self):
#
# ...
